# %%
import time
import ROOT
import numpy as np
import pandas as pd
import root_pandas as rpd
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
from root_pandas import read_root
# %run functions.ipynb
# %run constants.ipynb
# Out:
# Welcome to JupyROOT 6.14/06

# %%
eq = "Q = sqrt(Q2)"
xedges = [0, 0.004, 0.01, 0.05, 0.1]
largeQ2edges = [1,5000]

# %%
dataFiles = ["$HOME/fjpythia/output/723.root"]
a = getData(dataFiles)

d = applyCut(a, 'y > 0.01 and y < 0.85', '0.01 < y < 0.85')
d = applyCut(d, 'W2 > 4', 'W2 > 4')
d.eval(eq, inplace=True)
ls = applyCuts(d, xedges, largeQ2edges)
# Out:
# The history saving thread hit an unexpected error (DatabaseError('database disk image is malformed',)).History will not be written to the database.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b171f3234637> in <module>()
#       1 dataFiles = ["$HOME/fjpythia/output/723.root"]
# ----> 2 a = getData(dataFiles)
#       3
#       4 d = applyCut(a, 'y > 0.01 and y < 0.85', '0.01 < y < 0.85')
#       5 d = applyCut(d, 'W2 > 4', 'W2 > 4')
#
# NameError: name 'getData' is not defined

# %%
e = applyCut(d,'pt_jet > 4', 'pt_jet > 4')
e = applyCut(e, 'eta_jet < 0', 'eta_jet < 0')
es = applyCuts(e, xedges, largeQ2edges)
# Out:
# pt_jet > 4 994491  fraction kept: 3.4
# eta_jet < 0 440486  fraction kept: 44.3
#
# 1 < Q2 < 5000 GeV2
#
# 1 < Q2 < 5000 440486  fraction kept: 100.0
# 0 < x < 0.004 75924  fraction kept: 17.2
# 0.004 < x < 0.01 159680  fraction kept: 36.3
# 0.01 < x < 0.05 193944  fraction kept: 44.0
# 0.05 < x < 0.1 8822  fraction kept: 2.0

# %%
fig = plt.figure(figsize=(6,5))
plt.axvline(3.16,linewidth=1, color='white')
plt.axvline(4, linewidth=1, color='white')
plt.axvline(10, linewidth=1, color='white')
plt.axhline(3.16,linewidth=1, color='white')
plt.axhline(4, linewidth=1, color='white')
plt.axhline(10, linewidth=1, color='white')
plot2d(ls[0][0], 'Q', 'pt_quark', 'Q / GeV', '$p_{Tquark} / GeV$', 'Q^2 > 1 GeV^2, x < 0.004', '004_no',
      lim=(0,25,0,25))

# %%
fig = plt.figure(figsize=(6,5))
plt.axvline(3.16,linewidth=1, color='white')
plt.axvline(4, linewidth=1, color='white')
plt.axvline(10, linewidth=1, color='white')
plt.axhline(3.16,linewidth=1, color='white')
plt.axhline(4, linewidth=1, color='white')
plt.axhline(10, linewidth=1, color='white')
plot2d(es[0][0], 'Q', 'pt_quark', 'Q / GeV', '$p_{Tquark} / GeV$', 'Q^2 > 1 GeV^2, x < 0.004,$ \n $ p_{Tjet} > 4 GeV, \
       \eta_{jet} < 0', '004', lim=(0,25,0,25))

# %%
fig = plt.figure(figsize=(6,5))
plt.axvline(3.16,linewidth=1, color='white')
plt.axvline(4, linewidth=1, color='white')
plt.axvline(10, linewidth=1, color='white')
plt.axhline(3.16,linewidth=1, color='white')
plt.axhline(4, linewidth=1, color='white')
plt.axhline(10, linewidth=1, color='white')
plot2d(ls[0][1], 'Q', 'pt_quark', 'Q / GeV', '$p_{Tquark} / GeV$', 'Q^2 > 1 GeV^2, 0.004 < x < 0.01', '01_no',
      lim=(0,25,0,25))

# %%
fig = plt.figure(figsize=(6,5))
plt.axvline(3.16,linewidth=1, color='white')
plt.axvline(4, linewidth=1, color='white')
plt.axvline(10, linewidth=1, color='white')
plt.axhline(3.16,linewidth=1, color='white')
plt.axhline(4, linewidth=1, color='white')
plt.axhline(10, linewidth=1, color='white')
plot2d(es[0][1], 'Q', 'pt_quark', 'Q / GeV', '$p_{Tquark} / GeV$', 'Q^2 > 1 GeV^2, 0.004 < x < 0.01,$ \n $p_{Tjet} > 4 GeV, \
    \eta_{jet} < 0', '01', lim=(0,25,0,25))

# %%
fig = plt.figure(figsize=(6,5))
plt.axvline(3.16,linewidth=1, color='white')
plt.axvline(4, linewidth=1, color='white')
plt.axvline(10, linewidth=1, color='white')
plt.axhline(3.16,linewidth=1, color='white')
plt.axhline(4, linewidth=1, color='white')
plt.axhline(10, linewidth=1, color='white')
plot2d(ls[0][2], 'Q', 'pt_quark', 'Q / GeV', '$p_{Tquark} / GeV$', 'Q^2 > 1 GeV^2, 0.01 < x < 0.05', '05_no',
      lim=(0,25,0,25))

# %%
fig = plt.figure(figsize=(6,5))
plt.axvline(3.16,linewidth=1, color='white')
plt.axvline(4, linewidth=1, color='white')
plt.axvline(10, linewidth=1, color='white')
plt.axhline(3.16,linewidth=1, color='white')
plt.axhline(4, linewidth=1, color='white')
plt.axhline(10, linewidth=1, color='white')
plot2d(es[0][2], 'Q', 'pt_quark', 'Q / GeV', '$p_{Tquark} / GeV$', 'Q^2 > 1 GeV^2, 0.01 < x < 0.05,$ \n $p_{Tjet} > 4 GeV, \
    \eta_{jet} < 0','05', lim=(0,25,0,25))

# %%
fig = plt.figure(figsize=(6,5))
plt.axvline(3.16,linewidth=1, color='white')
plt.axvline(4, linewidth=1, color='white')
plt.axvline(10, linewidth=1, color='white')
plt.axhline(3.16,linewidth=1, color='white')
plt.axhline(4, linewidth=1, color='white')
plt.axhline(10, linewidth=1, color='white')
plot2d(ls[0][3], 'Q', 'pt_quark', 'Q / GeV', '$p_{Tquark} / GeV$', 'Q^2 > 1 GeV^2, 0.05 < x < 0.1', '1_no',
      lim=(0,25,0,25))

# %%
fig = plt.figure(figsize=(6,5))
plt.axvline(3.16,linewidth=1, color='white')
plt.axvline(4, linewidth=1, color='white')
plt.axvline(10, linewidth=1, color='white')
plt.axhline(3.16,linewidth=1, color='white')
plt.axhline(4, linewidth=1, color='white')
plt.axhline(10, linewidth=1, color='white')
plot2d(es[0][3], 'Q', 'pt_quark', 'Q / GeV', '$p_{Tquark} / GeV$', 'Q^2 > 1 GeV^2, 0.05 < x < 0.1,$ \n $p_{Tjet} > 4 GeV, \
    \eta_{jet} < 0','1', lim=(0,25,0,25))
