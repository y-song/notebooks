# %%
import time
import ROOT
import numpy as np
import pandas as pd
import root_pandas as rpd
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
from root_pandas import read_root
# %run functions.ipynb
# %run constants.ipynb
# Out:
# The history saving thread hit an unexpected error (DatabaseError('database disk image is malformed',)).History will not be written to the database.
# Welcome to JupyROOT 6.14/06

# %%
dataFiles = ["$HOME/fjpythia/output/723.root"]
a = getData(dataFiles)

d = keepOneJet(a)
d = applyCut(d, 'y > 0.01 and y < 0.85', '0.01 < y < 0.85')
d = applyCut(d, 'W2 > 4', 'W2 > 4')
d = applyCut(d, 'pt_electron > 4', 'pt_electron > 4')
eq = "Q = sqrt(Q2)"
d.eval(eq, inplace=True)
ds = applyCuts(d, xedges, largeQ2edges)
# Out:
# Processed $HOME/fjpythia/output/723.root in 88.1 seconds
#
# Remove extra jets 9523095  fraction kept: 21.7
# 0.01 < y < 0.85 5425935  fraction kept: 57.0
# W2 > 4 5425935  fraction kept: 100.0
# pt_electron > 4 363068  fraction kept: 6.7
#
# 1 < Q2 < 5000 GeV2
#
# 1 < Q2 < 5000 363068  fraction kept: 100.0
# 0.008 < x < 0.01 8470  fraction kept: 2.3
# 0.01 < x < 0.05 159075  fraction kept: 43.8
# 0.05 < x < 0.1 78007  fraction kept: 21.5
# 0.1 < x < 0.3 101889  fraction kept: 28.1
# 0.3 < x < 0.7 15471  fraction kept: 4.3

# %%
fig=plt.figure(figsize=(18,6))
plot1d(d, 'Q2', 0, 400, 1e4, 1e8, 5, '$ Q^2/GeV $', 'log', '$ 0.01 < y < 0.85, p_T^{electron} > 4 GeV $', 'Q2')

# %%
fig=plt.figure(figsize=(6,6))
plt.axvline(4, linewidth=1, color='red')
plot1d(ds[0][1], 'Q', 0, 25, 1e5, 1e8, 1, '$Q/GeV$', 'log', '0.008 < x < 0.01\n0.01 < y < 0.85, $p_{Tquark} > 4 GeV$', '01')

# %%
fig=plt.figure(figsize=(6,6))
plt.axvline(4, linewidth=1, color='red')
plot1d(ds[0][2], 'Q', 0, 25, 1e5, 1e8, 1, '$Q/GeV$', '0.01 < x < 0.05\n0.01 < y < 0.85, $p_{Tquark} > 4 GeV$', '05')

# %%
fig=plt.figure(figsize=(6,6))
plt.axvline(4, linewidth=1, color='red')
plot1d(ds[0][3], 'Q', 0, 25, 1e5, 1e8, 1, '$Q/GeV$', '0.05 < x < 0.1\n0.01 < y < 0.85, $p_{Tquark} > 4 GeV$', '1')
