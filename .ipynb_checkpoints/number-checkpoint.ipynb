# %%
import time
import ROOT
import numpy as np
import pandas as pd
import root_pandas as rpd
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
from root_pandas import read_root
# %run functions.ipynb
# %run constants.ipynb
# Out:
# The history saving thread hit an unexpected error (DatabaseError('database disk image is malformed',)).History will not be written to the database.
# Welcome to JupyROOT 6.14/06

# %%
def getData(inputFiles):
    cols = []
    scalar = []
    scalar.append('evid')
    scalar.append('ncharged')
    scalar.append('nneutral')
    scalar.append('pt_jet')
    scalar.append('p_jet')
    scalar.append('eta_jet')
    scalar.append('pt_electron')
    scalar.append('Q2')
    scalar.append('W2')
    scalar.append('x')
    scalar.append('y')
    scalar.append('xsec')
    scalar.append('ntrials')
    lists = scalar
    dataframes = []
    for inputFilename in inputFiles:
        start = time.time()
        df = read_root(inputFilename, columns=lists,flatten=cols)
        dataframes.append(df)
        end = time.time()
        print 'Processed', inputFilename, 'in',  end-start, 'seconds'
    return pd.concat([x for x in dataframes])

# %%
files = ['$HOME/fjpythia/output/723.root']
a = getData(files)
# Out:
# Processed $HOME/fjpythia/output/723.root in 52.225744009 seconds

# %%
d = applyCut(a, '0.01 < y < 0.85', '0.01 < y < 0.85')
d = applyCut(d, 'W2 > 4', 'W2 > 4')
d = applyCut(d, 'p_jet > 4', 'p_jet > 4')
d = applyCut(d, 'Q2 > 1', 'Q2 > 1')
d.eval('mult = nneutral + ncharged', inplace=True)
d1 = applyCut(d, 'pt_jet > 4 and pt_jet < 5', '4 < pt_jet < 5')
d2 = applyCut(d, 'pt_jet > 9 and pt_jet < 10', '9 < pt_jet < 10')
d3 = applyCut(d, 'pt_jet > 20 and pt_jet < 21', '20 < pt_jet < 21')
# Out:
# 0.01 < y < 0.85 28989288  fraction kept: 66.1
# W2 > 4 28989288  fraction kept: 100.0
# p_jet > 4 6775902  fraction kept: 23.4
# Q2 > 1 6775902  fraction kept: 100.0
# 4 < pt_jet < 5 358687  fraction kept: 5.3
# 9 < pt_jet < 10 40287  fraction kept: 0.6
# 20 < pt_jet < 21 1322  fraction kept: 0.0

# %%
def plot(df_array, label_array, color_array):
    for i in range(0,len(df_array)):
        plt.hist(df_array[i]['mult'], label='$ '+ label_array[i] + ' GeV$', range=(0,20), bins=20, histtype='step', fill=False, stacked=True, normed=True, color=color_array[i])

# %%
fig = plt.figure(figsize=(10,8))
plot([d1,d2,d3], ['4 < p_T^{jet} < 5','9 < p_T^{jet} < 10','20 < p_T^{jet} < 21'], ['b','r','g'])
plt.title('$ 0.01 < y < 0.85, Q^2 > 1 GeV^2$', fontsize=15)
plt.xlabel('Number of constituents per jet', fontsize=15)
plt.ylabel('Normalized counts', fontsize=15)
plt.xticks(np.arange(21), fontsize=15)
plt.yticks(fontsize=15)
plt.legend(prop={'size': 15}, frameon=False, loc='best')

# %%
colorArray = ['b','r','g','m','lawngreen','orange','indianred','skyblue']
labelArray = ['$\eta_{jet} < -3.0$','$-3.0 < \eta_{jet} < -2.0$','$-2.0 < \eta_{jet} < -1.0$','$-1.0 < \eta_{jet} < 0$',\
              '$0 < \eta_{jet} < 1.0$', '$1.0 < \eta_{jet} < 2.0$', '$2.0 < \eta_{jet} < 3.0$', '$\eta_{jet} > 3.0$']
etaedges = [-4.5, -3.0, -2.0, -1.0, 0, 1, 2, 3, 4.5]
ptedges = np.arange(26)
large_etaedges = [-4.5, 4.5]

# %%
a.eval('mult = nneutral + ncharged', inplace=True)
d = applyCut(a, 'Q2 > 10', 'Q2 > 10')
d = applyCut(d, 'y > 0.01 and y < 0.85', '0.01 < y < 0.85')
d = applyCut(d, 'W2 > 4', 'W2 > 4')
d = applyCut(d, 'p_jet > 5', 'p_jet > 5')

ds = partitionEtaPt(d, etaedges, ptedges)
# Out:
# Q2 > 10 4856516  fraction kept: 11.1
# 0.01 < y < 0.85 4477083  fraction kept: 92.2
# W2 > 4 4477083  fraction kept: 100.0
# p_jet > 5 1132129  fraction kept: 25.3
#
# -4.5 < eta_jet < -3.0
#
# -4.5 < eta_jet < -3.0 1820  fraction kept: 0.2
# 0 < pt_jet < 1 1644  fraction kept: 90.3
# 1 < pt_jet < 2 176  fraction kept: 9.7
# 2 < pt_jet < 3 0  fraction kept: 0.0
# 3 < pt_jet < 4 0  fraction kept: 0.0
# 4 < pt_jet < 5 0  fraction kept: 0.0
# 5 < pt_jet < 6 0  fraction kept: 0.0
# 6 < pt_jet < 7 0  fraction kept: 0.0
# 7 < pt_jet < 8 0  fraction kept: 0.0
# 8 < pt_jet < 9 0  fraction kept: 0.0
# 9 < pt_jet < 10 0  fraction kept: 0.0
# 10 < pt_jet < 11 0  fraction kept: 0.0
# 11 < pt_jet < 12 0  fraction kept: 0.0
# 12 < pt_jet < 13 0  fraction kept: 0.0
# 13 < pt_jet < 14 0  fraction kept: 0.0
# 14 < pt_jet < 15 0  fraction kept: 0.0
# 15 < pt_jet < 16 0  fraction kept: 0.0
# 16 < pt_jet < 17 0  fraction kept: 0.0
# 17 < pt_jet < 18 0  fraction kept: 0.0
# 18 < pt_jet < 19 0  fraction kept: 0.0
# 19 < pt_jet < 20 0  fraction kept: 0.0
# 20 < pt_jet < 21 0  fraction kept: 0.0
# 21 < pt_jet < 22 0  fraction kept: 0.0
# 22 < pt_jet < 23 0  fraction kept: 0.0
# 23 < pt_jet < 24 0  fraction kept: 0.0
# 24 < pt_jet < 25 0  fraction kept: 0.0
#
# -3.0 < eta_jet < -2.0
#
# -3.0 < eta_jet < -2.0 28920  fraction kept: 2.6
# 0 < pt_jet < 1 3451  fraction kept: 11.9
# 1 < pt_jet < 2 16004  fraction kept: 55.3
# 2 < pt_jet < 3 8229  fraction kept: 28.5
# 3 < pt_jet < 4 1212  fraction kept: 4.2
# 4 < pt_jet < 5 24  fraction kept: 0.1
# 5 < pt_jet < 6 0  fraction kept: 0.0
# 6 < pt_jet < 7 0  fraction kept: 0.0
# 7 < pt_jet < 8 0  fraction kept: 0.0
# 8 < pt_jet < 9 0  fraction kept: 0.0
# 9 < pt_jet < 10 0  fraction kept: 0.0
# 10 < pt_jet < 11 0  fraction kept: 0.0
# 11 < pt_jet < 12 0  fraction kept: 0.0
# 12 < pt_jet < 13 0  fraction kept: 0.0
# 13 < pt_jet < 14 0  fraction kept: 0.0
# 14 < pt_jet < 15 0  fraction kept: 0.0
# 15 < pt_jet < 16 0  fraction kept: 0.0
# 16 < pt_jet < 17 0  fraction kept: 0.0
# 17 < pt_jet < 18 0  fraction kept: 0.0
# 18 < pt_jet < 19 0  fraction kept: 0.0
# 19 < pt_jet < 20 0  fraction kept: 0.0
# 20 < pt_jet < 21 0  fraction kept: 0.0
# 21 < pt_jet < 22 0  fraction kept: 0.0
# 22 < pt_jet < 23 0  fraction kept: 0.0
# 23 < pt_jet < 24 0  fraction kept: 0.0
# 24 < pt_jet < 25 0  fraction kept: 0.0
#
# -2.0 < eta_jet < -1.0
#
# -2.0 < eta_jet < -1.0 94308  fraction kept: 8.3
# 0 < pt_jet < 1 0  fraction kept: 0.0
# 1 < pt_jet < 2 5920  fraction kept: 6.3
# 2 < pt_jet < 3 29214  fraction kept: 31.0
# 3 < pt_jet < 4 32112  fraction kept: 34.1
# 4 < pt_jet < 5 15631  fraction kept: 16.6
# 5 < pt_jet < 6 6601  fraction kept: 7.0
# 6 < pt_jet < 7 2899  fraction kept: 3.1
# 7 < pt_jet < 8 1223  fraction kept: 1.3
# 8 < pt_jet < 9 484  fraction kept: 0.5
# 9 < pt_jet < 10 166  fraction kept: 0.2
# 10 < pt_jet < 11 44  fraction kept: 0.0
# 11 < pt_jet < 12 14  fraction kept: 0.0
# 12 < pt_jet < 13 0  fraction kept: 0.0
# 13 < pt_jet < 14 0  fraction kept: 0.0
# 14 < pt_jet < 15 0  fraction kept: 0.0
# 15 < pt_jet < 16 0  fraction kept: 0.0
# 16 < pt_jet < 17 0  fraction kept: 0.0
# 17 < pt_jet < 18 0  fraction kept: 0.0
# 18 < pt_jet < 19 0  fraction kept: 0.0
# 19 < pt_jet < 20 0  fraction kept: 0.0
# 20 < pt_jet < 21 0  fraction kept: 0.0
# 21 < pt_jet < 22 0  fraction kept: 0.0
# 22 < pt_jet < 23 0  fraction kept: 0.0
# 23 < pt_jet < 24 0  fraction kept: 0.0
# 24 < pt_jet < 25 0  fraction kept: 0.0
#
# -1.0 < eta_jet < 0
#
# -1.0 < eta_jet < 0 85990  fraction kept: 7.6
# 0 < pt_jet < 1 0  fraction kept: 0.0
# 1 < pt_jet < 2 0  fraction kept: 0.0
# 2 < pt_jet < 3 0  fraction kept: 0.0
# 3 < pt_jet < 4 5186  fraction kept: 6.0
# 4 < pt_jet < 5 18116  fraction kept: 21.1
# 5 < pt_jet < 6 22381  fraction kept: 26.0
# 6 < pt_jet < 7 13808  fraction kept: 16.1
# 7 < pt_jet < 8 8906  fraction kept: 10.4
# 8 < pt_jet < 9 5648  fraction kept: 6.6
# 9 < pt_jet < 10 3904  fraction kept: 4.5
# 10 < pt_jet < 11 2667  fraction kept: 3.1
# 11 < pt_jet < 12 1823  fraction kept: 2.1
# 12 < pt_jet < 13 1195  fraction kept: 1.4
# 13 < pt_jet < 14 808  fraction kept: 0.9
# 14 < pt_jet < 15 512  fraction kept: 0.6
# 15 < pt_jet < 16 374  fraction kept: 0.4
# 16 < pt_jet < 17 233  fraction kept: 0.3
# 17 < pt_jet < 18 153  fraction kept: 0.2
# 18 < pt_jet < 19 93  fraction kept: 0.1
# 19 < pt_jet < 20 70  fraction kept: 0.1
# 20 < pt_jet < 21 51  fraction kept: 0.1
# 21 < pt_jet < 22 26  fraction kept: 0.0
# 22 < pt_jet < 23 18  fraction kept: 0.0
# 23 < pt_jet < 24 9  fraction kept: 0.0
# 24 < pt_jet < 25 5  fraction kept: 0.0
#
# 0 < eta_jet < 1
#
# 0 < eta_jet < 1 119585  fraction kept: 10.6
# 0 < pt_jet < 1 0  fraction kept: 0.0
# 1 < pt_jet < 2 0  fraction kept: 0.0
# 2 < pt_jet < 3 0  fraction kept: 0.0
# 3 < pt_jet < 4 5922  fraction kept: 5.0
# 4 < pt_jet < 5 21731  fraction kept: 18.2
# 5 < pt_jet < 6 26706  fraction kept: 22.3
# 6 < pt_jet < 7 18128  fraction kept: 15.2
# 7 < pt_jet < 8 12285  fraction kept: 10.3
# 8 < pt_jet < 9 8661  fraction kept: 7.2
# 9 < pt_jet < 10 6459  fraction kept: 5.4
# 10 < pt_jet < 11 4730  fraction kept: 4.0
# 11 < pt_jet < 12 3532  fraction kept: 3.0
# 12 < pt_jet < 13 2719  fraction kept: 2.3
# 13 < pt_jet < 14 1981  fraction kept: 1.7
# 14 < pt_jet < 15 1527  fraction kept: 1.3
# 15 < pt_jet < 16 1223  fraction kept: 1.0
# 16 < pt_jet < 17 957  fraction kept: 0.8
# 17 < pt_jet < 18 741  fraction kept: 0.6
# 18 < pt_jet < 19 563  fraction kept: 0.5
# 19 < pt_jet < 20 443  fraction kept: 0.4
# 20 < pt_jet < 21 324  fraction kept: 0.3
# 21 < pt_jet < 22 263  fraction kept: 0.2
# 22 < pt_jet < 23 181  fraction kept: 0.2
# 23 < pt_jet < 24 149  fraction kept: 0.1
# 24 < pt_jet < 25 121  fraction kept: 0.1
#
# 1 < eta_jet < 2
#
# 1 < eta_jet < 2 204067  fraction kept: 18.0
# 0 < pt_jet < 1 0  fraction kept: 0.0
# 1 < pt_jet < 2 10800  fraction kept: 5.3
# 2 < pt_jet < 3 33811  fraction kept: 16.6
# 3 < pt_jet < 4 48947  fraction kept: 24.0
# 4 < pt_jet < 5 37223  fraction kept: 18.2
# 5 < pt_jet < 6 24399  fraction kept: 12.0
# 6 < pt_jet < 7 15484  fraction kept: 7.6
# 7 < pt_jet < 8 10156  fraction kept: 5.0
# 8 < pt_jet < 9 6897  fraction kept: 3.4
# 9 < pt_jet < 10 4788  fraction kept: 2.3
# 10 < pt_jet < 11 3370  fraction kept: 1.7
# 11 < pt_jet < 12 2294  fraction kept: 1.1
# 12 < pt_jet < 13 1696  fraction kept: 0.8
# 13 < pt_jet < 14 1153  fraction kept: 0.6
# 14 < pt_jet < 15 858  fraction kept: 0.4
# 15 < pt_jet < 16 609  fraction kept: 0.3
# 16 < pt_jet < 17 449  fraction kept: 0.2
# 17 < pt_jet < 18 309  fraction kept: 0.2
# 18 < pt_jet < 19 266  fraction kept: 0.1
# 19 < pt_jet < 20 163  fraction kept: 0.1
# 20 < pt_jet < 21 116  fraction kept: 0.1
# 21 < pt_jet < 22 80  fraction kept: 0.0
# 22 < pt_jet < 23 74  fraction kept: 0.0
# 23 < pt_jet < 24 42  fraction kept: 0.0
# 24 < pt_jet < 25 35  fraction kept: 0.0
#
# 2 < eta_jet < 3
#
# 2 < eta_jet < 3 302010  fraction kept: 26.7
# 0 < pt_jet < 1 102308  fraction kept: 33.9
# 1 < pt_jet < 2 104598  fraction kept: 34.6
# 2 < pt_jet < 3 27233  fraction kept: 9.0
# 3 < pt_jet < 4 24346  fraction kept: 8.1
# 4 < pt_jet < 5 18556  fraction kept: 6.1
# 5 < pt_jet < 6 11316  fraction kept: 3.7
# 6 < pt_jet < 7 6136  fraction kept: 2.0
# 7 < pt_jet < 8 3368  fraction kept: 1.1
# 8 < pt_jet < 9 1931  fraction kept: 0.6
# 9 < pt_jet < 10 1023  fraction kept: 0.3
# 10 < pt_jet < 11 567  fraction kept: 0.2
# 11 < pt_jet < 12 273  fraction kept: 0.1
# 12 < pt_jet < 13 157  fraction kept: 0.1
# 13 < pt_jet < 14 76  fraction kept: 0.0
# 14 < pt_jet < 15 53  fraction kept: 0.0
# 15 < pt_jet < 16 30  fraction kept: 0.0
# 16 < pt_jet < 17 22  fraction kept: 0.0
# 17 < pt_jet < 18 7  fraction kept: 0.0
# 18 < pt_jet < 19 3  fraction kept: 0.0
# 19 < pt_jet < 20 3  fraction kept: 0.0
# 20 < pt_jet < 21 1  fraction kept: 0.0
# 21 < pt_jet < 22 1  fraction kept: 0.0
# 22 < pt_jet < 23 0  fraction kept: 0.0
# 23 < pt_jet < 24 1  fraction kept: 0.0
# 24 < pt_jet < 25 0  fraction kept: 0.0
#
# 3 < eta_jet < 4.5
#
# 3 < eta_jet < 4.5 295429  fraction kept: 26.1
# 0 < pt_jet < 1 227536  fraction kept: 77.0
# 1 < pt_jet < 2 58782  fraction kept: 19.9
# 2 < pt_jet < 3 6413  fraction kept: 2.2
# 3 < pt_jet < 4 1462  fraction kept: 0.5
# 4 < pt_jet < 5 566  fraction kept: 0.2
# 5 < pt_jet < 6 303  fraction kept: 0.1
# 6 < pt_jet < 7 213  fraction kept: 0.1
# 7 < pt_jet < 8 115  fraction kept: 0.0
# 8 < pt_jet < 9 36  fraction kept: 0.0
# 9 < pt_jet < 10 3  fraction kept: 0.0
# 10 < pt_jet < 11 0  fraction kept: 0.0
# 11 < pt_jet < 12 0  fraction kept: 0.0
# 12 < pt_jet < 13 0  fraction kept: 0.0
# 13 < pt_jet < 14 0  fraction kept: 0.0
# 14 < pt_jet < 15 0  fraction kept: 0.0
# 15 < pt_jet < 16 0  fraction kept: 0.0
# 16 < pt_jet < 17 0  fraction kept: 0.0
# 17 < pt_jet < 18 0  fraction kept: 0.0
# 18 < pt_jet < 19 0  fraction kept: 0.0
# 19 < pt_jet < 20 0  fraction kept: 0.0
# 20 < pt_jet < 21 0  fraction kept: 0.0
# 21 < pt_jet < 22 0  fraction kept: 0.0
# 22 < pt_jet < 23 0  fraction kept: 0.0
# 23 < pt_jet < 24 0  fraction kept: 0.0
# 24 < pt_jet < 25 0  fraction kept: 0.0

# %%
fig = plt.figure(figsize=(10,6))
for i in range(len(etaedges)-1):
    x = []*(len(ptedges)-1)
    y = []*(len(ptedges)-1)
    yerr = []*(len(ptedges)-1)
    for j in range(len(ptedges)-1):
        df = ds[i][j]
        x.append((((float)(ptedges[j])) + ptedges[j+1])/2)
        y.append(np.mean(df['mult']))
        xerr = getInterval(ptedges)/2
        yerr.append(np.std(df['mult'])/2)
    plt.errorbar(x, y, xerr = xerr, yerr = yerr, color=colorArray[i], elinewidth=1, label=labelArray[i])
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.xlabel('$p_T^{jet} / GeV$', fontsize=15)
plt.ylabel('Number of Constituents', fontsize=15)
plt.legend(prop={'size': 12.5}, frameon=False, loc='upper left')
print 'Cuts: Q2 > 10 GeV^2, p_jet > 5 GeV, 0.01 < y < 0.85, W2 > 4 GeV^2'
# Out:
# Cuts: Q2 > 10 GeV^2, p_jet > 5 GeV, 0.01 < y < 0.85, W2 > 4 GeV^2

# %%
fig = plt.figure(figsize=(10,6))
for i in range(len(etaedges)-1):
    x = []*(len(ptedges)-1)
    y = []*(len(ptedges)-1)
    yerr = []*(len(ptedges)-1)
    for j in range(len(ptedges)-1):
        df = ds[i][j]
        x.append((((float)(ptedges[j])) + ptedges[j+1])/2)
        y.append(np.mean(df['ncharged']))
        xerr = getInterval(ptedges)/2
        yerr.append(np.std(df['ncharged'])/2)
    plt.errorbar(x, y, xerr = xerr, yerr = yerr, color=colorArray[i], elinewidth=1, label=labelArray[i])
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.xlabel('$p_T^{jet} / GeV$', fontsize=15)
plt.ylabel('Number of Charged Constituents', fontsize=15)
plt.legend(prop={'size': 12.5}, frameon=False, loc='upper left')
print 'Cuts: Q2 > 10 GeV^2, p_jet > 5 GeV, 0.01 < y < 0.85, W2 > 4 GeV^2'
# Out:
# Cuts: Q2 > 10 GeV^2, p_jet > 5 GeV, 0.01 < y < 0.85, W2 > 4 GeV^2

# %%
d = applyCut(a, 'Q2 > 1', 'Q2 > 1')
d = applyCut(d, 'y > 0.01 and y< 0.85', '0.01 < y< 0.85')
d = applyCut(d, 'W2 > 4', 'W2 > 4')

ds_large = partitionEtaPt(d, large_etaedges, ptedges)
# Out:
# Q2 > 1 43881058  fraction kept: 100.0
# 0.01 < y< 0.85 28989288  fraction kept: 66.1
# W2 > 4 28989288  fraction kept: 100.0
#
# -4.5 < eta_jet < 4.5
#
# -4.5 < eta_jet < 4.5 28989288  fraction kept: 100.0
# 0 < pt_jet < 1 21520399  fraction kept: 74.2
# 1 < pt_jet < 2 4392981  fraction kept: 15.2
# 2 < pt_jet < 3 1419607  fraction kept: 4.9
# 3 < pt_jet < 4 661809  fraction kept: 2.3
# 4 < pt_jet < 5 358687  fraction kept: 1.2
# 5 < pt_jet < 6 214440  fraction kept: 0.7
# 6 < pt_jet < 7 134172  fraction kept: 0.5
# 7 < pt_jet < 8 86841  fraction kept: 0.3
# 8 < pt_jet < 9 57991  fraction kept: 0.2
# 9 < pt_jet < 10 40287  fraction kept: 0.1
# 10 < pt_jet < 11 27863  fraction kept: 0.1
# 11 < pt_jet < 12 19673  fraction kept: 0.1
# 12 < pt_jet < 13 14399  fraction kept: 0.0
# 13 < pt_jet < 14 10402  fraction kept: 0.0
# 14 < pt_jet < 15 7729  fraction kept: 0.0
# 15 < pt_jet < 16 5696  fraction kept: 0.0
# 16 < pt_jet < 17 4253  fraction kept: 0.0
# 17 < pt_jet < 18 3157  fraction kept: 0.0
# 18 < pt_jet < 19 2393  fraction kept: 0.0
# 19 < pt_jet < 20 1781  fraction kept: 0.0
# 20 < pt_jet < 21 1322  fraction kept: 0.0
# 21 < pt_jet < 22 985  fraction kept: 0.0
# 22 < pt_jet < 23 742  fraction kept: 0.0
# 23 < pt_jet < 24 489  fraction kept: 0.0
# 24 < pt_jet < 25 377  fraction kept: 0.0

# %%
fig = plt.figure(figsize=(10,6))
for i in range(len(large_etaedges)-1):
    x = []*(len(ptedges)-1)
    y = []*(len(ptedges)-1)
    yerr = []*(len(ptedges)-1)
    for j in range(len(ptedges)-1):
        df = ds_large[i][j]
        x.append((((float)(ptedges[j])) + ptedges[j+1])/2)
        y.append(np.mean(df['mult']))
        xerr = getInterval(ptedges)/2
        yerr.append(np.std(df['mult'])/2)
    plt.errorbar(x, y, xerr = xerr, yerr = yerr, color=colorArray[i], elinewidth=1, label=labelArray[i])
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.xlabel('$p_T^{jet} / GeV$', fontsize=15)
plt.ylabel('Number of Constituents', fontsize=15)
plt.title('$ 0.01 < y < 0.85, Q^2 > 1 GeV^2$', fontsize=15)
# Out:
# Text(0.5,1,'$ 0.01 < y < 0.85, Q^2 > 1 GeV^2$')
