# %%
import time
import ROOT
import numpy as np
import pandas as pd
import root_pandas as rpd
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
from root_pandas import read_root
# %run functions.ipynb
# %run constants.ipynb
# Out:
# The history saving thread hit an unexpected error (DatabaseError('database disk image is malformed',)).History will not be written to the database.
# Welcome to JupyROOT 6.14/06

# %%
def getData(inputFiles):
    cols = []
    scalar = []
    scalar.append('evid')
    scalar.append('xsec')
    scalar.append('ntrials')    
    scalar.append('x')
    scalar.append('y')
    scalar.append('Q2')
    scalar.append('W2')
    scalar.append('pt_jet')
    scalar.append('eta_jet')
    scalar.append('phi_jet')
    scalar.append('pt_quark')
    scalar.append('eta_quark')
    scalar.append('phi_quark')
    scalar.append('pt_photon')
    scalar.append('phi_photon')
    scalar.append('eta_electron')
    scalar.append('pt_electron')
    scalar.append('delta_R')
    lists = scalar
    dataframes = []
    for inputFilename in inputFiles:
        start = time.time()
        df = read_root(inputFilename, columns=lists,flatten=cols)
        dataframes.append(df)
        end = time.time()
        print '\n', 'Processed', inputFilename, 'in',  '%2.1f'%(end-start), 'seconds'
    return pd.concat([x for x in dataframes])

# %%
files = ["$HOME/fjpythia/output/925.root"]
a = getData(files)
# Out:
# Processed $HOME/fjpythia/output/925.root in 112.1 seconds

# %%
c = applyCut(a, 'pt_electron > 4', 'pt_electron > 4')
c = applyCut(c, 'pt_jet > 4', 'pt_jet > 4')
c = applyCut(c, '0.01 < y < 0.85', '0.01 < y < 0.85')
c = fixPhi(c, 'photon')
# Out:
# pt_electron > 4 1926302  fraction kept: 4.4
# pt_jet > 4 306054  fraction kept: 15.9
# 0.01 < y < 0.85 292545  fraction kept: 95.6
# Fixed photon phi range
# Fixed photon delta phi range

# %%
c = applyCut(c, 'delta_phi_photon_abs < 0.4', 'delta_phi_photon_abs < 0.4')
c1 = applyCut(c, '5 < pt_electron < 10', '5 < pt_electron < 10')
c2 = applyCut(c, '10 < pt_electron < 15', '10 < pt_electron < 15')
c3 = applyCut(c, '20 < pt_electron < 30', '20 < pt_electron < 30')
# Out:
# delta_phi_photon_abs < 0.4 233933  fraction kept: 80.0
# 5 < pt_electron < 10 143296  fraction kept: 61.3
# 10 < pt_electron < 15 17233  fraction kept: 7.4
# 20 < pt_electron < 30 950  fraction kept: 0.4

# %%
def plot_r(df_array, var_array, label_array, color_array):
    for i in range(0,len(var_array)):
        fig = plt.hist(df_array[i][var_array[i]], label=label_array[i], range=(0,1.0), bins=10, histtype='step', fill=True, alpha=0.5, stacked=True, normed=True, color=color_array[i], linewidth=2)
    return fig

# %%
files = ["$HOME/fjpythia/output/929.root"]
a = getData(files)
# Out:
# Processed $HOME/fjpythia/output/929.root in 75.9 seconds

# %%
d = applyCut(a, 'pt_electron > 4', 'pt_electron > 4')
d = applyCut(d, 'pt_jet > 4', 'pt_jet > 4')
d = applyCut(d, '0.01 < y < 0.85', '0.01 < y < 0.85')
d = fixPhi(d, 'photon')
# Out:
# pt_electron > 4 1926302  fraction kept: 4.4
# pt_jet > 4 306054  fraction kept: 15.9
# 0.01 < y < 0.85 292545  fraction kept: 95.6
# Fixed photon phi range
# Fixed photon delta phi range

# %%
d = applyCut(d, 'delta_phi_photon_abs < 0.4', 'delta_phi_photon_abs < 0.4')
d1 = applyCut(d, '5 < pt_electron < 10', '5 < pt_electron < 10')
d2 = applyCut(d, '10 < pt_electron < 15', '10 < pt_electron < 15')
d3 = applyCut(d, '20 < pt_electron < 30', '20 < pt_electron < 30')
# Out:
# delta_phi_photon_abs < 0.4 233933  fraction kept: 80.0
# 5 < pt_electron < 10 143296  fraction kept: 61.3
# 10 < pt_electron < 15 17233  fraction kept: 7.4
# 20 < pt_electron < 30 950  fraction kept: 0.4

# %%
fig = plt.figure(figsize=(20,6))
plt.subplots_adjust(wspace=0, hspace=0)

ax1 = plt.subplot(131)
plot_r([c1,d1], ['delta_R','delta_R'], [r'$\beta=0.0$',r'$\beta=2.0$'], ['b','r'])
plt.xlabel('$R_g$', fontsize=15)
plt.ylabel('Normalized counts', fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.legend(prop={'size': 15}, frameon=False, loc='best')
plt.title('$5 < p_T^{electron} < 10 GeV$', fontsize=15)

ax2 = plt.subplot(132, sharey=ax1)
plot_r([c2,d2], ['delta_R','delta_R'], [r'$\beta=0.0$',r'$\beta=2.0$'], ['b','r'])
plt.xlabel('$R_g$', fontsize=15)
plt.xticks(fontsize=15)
plt.setp(ax2.get_yticklabels(), visible=False)
plt.text(0,1.8,'$\sqrt{s} = 89 GeV$ \n $0.01 < y < 0.85$ \n $|\Delta \phi| < 0.4$ \n $p_T^{jet} > 4 GeV$ \n Soft drop: $z_{min} = 0.1$', fontsize=15)
plt.legend(prop={'size': 15}, frameon=False, loc='best')
plt.title('$10 < p_T^{electron} < 15 GeV$', fontsize=15)

ax3 = plt.subplot(133, sharey=ax1)
plot_r([c3,d3], ['delta_R','delta_R'], [r'$\beta=0.0$',r'$\beta=2.0$'], ['b','r'])
plt.xlabel('$R_g$', fontsize=15)
plt.xticks(fontsize=15)
plt.setp(ax3.get_yticklabels(), visible=False)
plt.legend(prop={'size': 15}, frameon=False, loc='best')
plt.title('$20 < p_T^{electron} < 30 GeV$', fontsize=15)

plt.savefig('images/deltar_1.pdf', bbox_inches='tight')

# %%
fig = plt.figure(figsize=(10,8))
plot([d1,d2,d3], ['5 < p_T^{electron} < 10','10 < p_T^{electron} < 15','20 < p_T^{electron} < 30'], ['b','r','g'])
plt.xlabel('Groomed jet radius $R_g$', fontsize=15)
plt.ylabel('Normalized counts', fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.text(0.7, 1.5, '$\sqrt{s} = 89 GeV$ \n $0.01 < y < 0.85$ \n $|\Delta \phi| < 0.4$ \n $p_T^{jet} > 4 GeV$ \n $z_{min} = 1.0$ \n' + r'$\beta = 0.0$', fontsize=15)
plt.legend(prop={'size': 15}, frameon=False, loc='best')
plt.savefig('images/delta_R.pdf', bbox_inches='tight')

# %%
plt.figure(figsize=(10,8))
plot1d(d, 'delta_R', 0, 1.1, 0, 2e6, 0.1, 'Groomed jet radius $R_g$', 'linear', '', 'delta_R')
plt.text(0.7, 0, '$\sqrt{s} = 89 GeV$ \n $0.01 < y < 0.85$ \n $Q^2 > 1 GeV^2$ \n $p_T^{jet} > 4 GeV$ \n $p_T^{electron} > 4 GeV$', fontsize = 15)
plt.savefig('images/delta_R.pdf', bbox_inches='tight')
