# %%
import time
import ROOT
import numpy as np
import pandas as pd
import root_pandas as rpd
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
from root_pandas import read_root
# %run functions.ipynb
# %run constants.ipynb
# Out:
# The history saving thread hit an unexpected error (DatabaseError('database disk image is malformed',)).History will not be written to the database.
# Welcome to JupyROOT 6.14/06

# %%
dataFiles = ["$HOME/fjpythia/output/723.root"]
a = getData(dataFiles)

d = keepOneJet(a)
d = applyCut(d, 'y > 0.01 and y < 0.85', '0.01 < y < 0.85')
d = applyCut(d, 'W2 > 4', 'W2 > 4')
d = applyCut(d, 'pt_quark > 4', 'pt_quark > 4')
ds = applyCuts(d, xedges, largeQ2edges)
# Out:
# Processed $HOME/fjpythia/output/723.root in 87.8644559383 seconds
#
# Remove extra jets 9523095  fraction kept: 21.7
# 0.01 < y < 0.85 5425935  fraction kept: 57.0
# W2 > 4 5425935  fraction kept: 100.0
# pt_quark > 4 363068  fraction kept: 6.7
#
# 1 < Q2 < 5000 GeV2
#
# 1 < Q2 < 5000 363068  fraction kept: 100.0
# 0 < x < 0.008 0  fraction kept: 0.0
# 0.008 < x < 0.01 8470  fraction kept: 2.3
# 0.01 < x < 0.05 159075  fraction kept: 43.8
# 0.05 < x < 0.1 78007  fraction kept: 21.5

# %%
print min(d['x'])
# Out:
# 0.00800042413175

# %%
fig = plt.figure(figsize=(6,6))
plot1d(ds[0][1], 'eta_quark', -4.5, 4.5, 1e5, 1e8, 0.25, '$\eta_{quark}$', 'log', '0.008 < x < 0.01 \n 0.01 < y < 0.85, $p_{Tquark} > 4 GeV$', '01')

# %%
fig = plt.figure(figsize=(6,6))
plot1d(ds[0][2], 'eta_quark', -4.5, 4.5, 1e5, 1e8, 0.25, '$\eta_{quark}$', '0.01 < x < 0.05 \n 0.01 < y < 0.85, $p_{Tquark} > 4 GeV$', '05')

# %%
fig = plt.figure(figsize=(6,6))
plot1d(ds[0][3], 'eta_quark', -4.5, 4.5, 1e5, 1e8, 0.25, '$\eta_{quark}$', '0.05 < x < 0.1 \n 0.01 < y < 0.85, $p_{Tquark} > 4 GeV$', '1')
